# %% [markdown]
# <a href="https://colab.research.google.com/github/MellowFluff/Explicit-Lyrics-classifier/blob/main/label_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/labeledlyricsallfixed.csv')
#df = df0['explicit_score']
df
# Out:
#                title               artist  \
# 0       White  Nerdy  "Weird Al" Yankovic
# 1       White  Nerdy  "Weird Al" Yankovic
# 2       White  Nerdy  "Weird Al" Yankovic
# 3       White  Nerdy  "Weird Al" Yankovic
# 4       White  Nerdy  "Weird Al" Yankovic
# ...              ...                  ...
# 129656      Hands Up                eLZhi
# 129657      Hands Up                eLZhi
# 129658      Hands Up                eLZhi
# 129659      Hands Up                eLZhi
# 129660      Hands Up                eLZhi
#
#                                                    lyrics  text_order  \
# 0                        They see me mowin' my front lawn           1
# 1       I know they're all thinking I'm so white and n...           2
# 2                          I wanna roll with the gangstas           3
# 3       But so far they all think I'm too white and nerdy           4
# 4                          Really, really white and nerdy           5
# ...

# %%
label = []

for ind in df.index:
    score = df['explicit_score'][ind]
    if score <= 0.55:
        lab = 0
    else:
        lab = 1
    label.append(lab)

# %%
# Create the 'label' column based on the condition
df['label'] = df['explicit_score'].apply(lambda score: 0 if score <= 0.55 else 1)

# Create 'explicit' and 'non-explicit' columns based on the 'label' column
df['explicit'] = df['label'].apply(lambda label: 1 if label == 1 else 0)
df['non-explicit'] = df['label'].apply(lambda label: 1 if label == 0 else 0)

# Drop the 'label' column if you don't need it
df.drop(['label'], axis=1, inplace=True)

# %%
df['explicit_count'] = pd.Series(label)

# %%
df
# Out:
#                title               artist  \
# 0       White  Nerdy  "Weird Al" Yankovic
# 1       White  Nerdy  "Weird Al" Yankovic
# 2       White  Nerdy  "Weird Al" Yankovic
# 3       White  Nerdy  "Weird Al" Yankovic
# 4       White  Nerdy  "Weird Al" Yankovic
# ...              ...                  ...
# 129656      Hands Up                eLZhi
# 129657      Hands Up                eLZhi
# 129658      Hands Up                eLZhi
# 129659      Hands Up                eLZhi
# 129660      Hands Up                eLZhi
#
#                                                    lyrics  text_order  \
# 0                        They see me mowin' my front lawn           1
# 1       I know they're all thinking I'm so white and n...           2
# 2                          I wanna roll with the gangstas           3
# 3       But so far they all think I'm too white and nerdy           4
# 4                          Really, really white and nerdy           5
# ...

# %%
df.to_csv('trainingdatacomplete.csv')
